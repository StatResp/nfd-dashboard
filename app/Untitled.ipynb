# %%
import pandas as pd

# %%
df =pd.read_parquet('tdot_incidents.parquet', engine='pyarrow')

# %%
df.dtypes
# Out:
# log_mle                                float64
# county_incident                         object
# route                                   object
# latitude                               float64
# longitude                              float64
# type_of_crash                           object
# total_killed                             int32
# total_injured                            int32
# total_incapcitating_injuries             int32
# total_other_injuries                     int32
# total_vehicles                           int32
# hazmat_involved                         object
# hit_and_run                             object
# id_original                             object
# on_highway_type                         object
# rail_crossing_identifier                object
# relation_to_first_junction              object
# relation_to_first_rdway                 object
# school_bus_related                      object
# traffic_land_private_way                object
# ...

# %%
df.frc.unique()
# Out:
# array([ 0.,  1., nan,  2.,  4.,  3.])

# %%
df[df.frc==0]
# Out:
#         log_mle county_incident  route   latitude  longitude  \
# 0        15.538          shelby  I0240  35.101212 -89.870687
# 5         7.325       robertson  I0065  36.508030 -86.658350
# 13       18.404          mcminn  I0075  35.517290 -84.596900
# 18       22.159        sullivan  SR001  36.592747 -82.241460
# 20        2.447       robertson  I0024  36.446250 -87.092940
# ...         ...             ...    ...        ...        ...
# 819827    5.785          blount  SR073  35.755400 -84.077580
# 819829    7.117      cumberland  I0040  36.047880 -85.136870
# 819837   14.034          blount  SR073  35.755780 -83.936300
# 819840    5.228      montgomery  SR076  36.539870 -87.534070
# 819841   12.608           roane  I0040  35.878740 -84.504490
#
#                    type_of_crash  total_killed  total_injured  \
# 0             Prop Damage (over)             0              1
# 5             Prop Damage (over)             0              1
# ...

# %%
df
# Out:
#         log_mle county_incident  route   latitude  longitude  \
# 0        15.538          shelby  I0240  35.101212 -89.870687
# 1         0.344          shelby  02830  35.050982 -89.901724
# 2         1.970          shelby  02814  35.062465 -89.905885
# 3         0.739            dyer  0A827  36.019680 -89.391860
# 4        11.016         decatur  SR202  35.592360 -88.144390
# ...         ...             ...    ...        ...        ...
# 819838    1.180          warren  0A469  35.593600 -85.893740
# 819839   12.820          shelby  00811  35.226589 -89.738996
# 819840    5.228      montgomery  SR076  36.539870 -87.534070
# 819841   12.608           roane  I0040  35.878740 -84.504490
# 819842   15.517       henderson  SR104  35.673210 -88.430330
#
#                    type_of_crash  total_killed  total_injured  \
# 0             Prop Damage (over)             0              1
# 1             Prop Damage (over)             0              2
# ...
